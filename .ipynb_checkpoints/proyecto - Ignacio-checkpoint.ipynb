# %%
#librerias
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Filtrado de datos**

# %% [markdown]
# 1) Filtrado del dataset  del rendimiento academico 2021 de Alumnos de cuarto medio (edad = 17 y edad = 18) Ad portas de entrar a la universidad

# %%
df_rendimiento = pd.read_csv('Dataframes/20220302_Rendimiento_2021_20220131_WEB.csv', sep = ';',  decimal=",")
df_rendimiento
# Out:
# C:\Users\ibgar\AppData\Local\Temp\ipykernel_9964\3200872040.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_rendimiento = pd.read_csv('Dataframes/20220302_Rendimiento_2021_20220131_WEB.csv', sep = ';',  decimal=",")
#          AGNO    RBD  DGV_RBD                           NOM_RBD  COD_REG_RBD  \
# 0        2021      1        9           LICEO POLITECNICO ARICA           15
# 1        2021      1        9           LICEO POLITECNICO ARICA           15
# 2        2021      1        9           LICEO POLITECNICO ARICA           15
# 3        2021      1        9           LICEO POLITECNICO ARICA           15
# 4        2021      1        9           LICEO POLITECNICO ARICA           15
# ...       ...    ...      ...                               ...          ...
# 3237038  2021  41955        9  ESCUELA HOSPITALARIA LOS ÁNGELES            8
# 3237039  2021  41955        9  ESCUELA HOSPITALARIA LOS ÁNGELES            8
# 3237040  2021  41955        9  ESCUELA HOSPITALARIA LOS ÁNGELES            8
# 3237041  2021  41955        9  ESCUELA HOSPITALARIA LOS ÁNGELES            8
# 3237042  2021  41955        9  ESCUELA HOSPITALARIA LOS ÁNGELES            8
#
#         NOM_REG_RBD_A  COD_PRO_RBD  COD_COM_RBD  NOM_COM_RBD  COD_DEPROV_RBD  \
# 0                 AYP          151        15101        ARICA             151
# 1                 AYP          151        15101        ARICA             151
# 2                 AYP          151        15101        ARICA             151
# 3                 AYP          151        15101        ARICA             151
# 4                 AYP          151        15101        ARICA             151
# ...               ...          ...          ...          ...             ...
# 3237038          BBIO           83         8301  LOS ÁNGELES              82
# 3237039          BBIO           83         8301  LOS ÁNGELES              82
# 3237040          BBIO           83         8301  LOS ÁNGELES              82
# 3237041          BBIO           83         8301  LOS ÁNGELES              82
# 3237042          BBIO           83         8301  LOS ÁNGELES              82
#
#          ... COD_COM_ALU  NOM_COM_ALU  COD_RAMA  COD_SEC  COD_ESPE  PROM_GRAL  \
# 0        ...       15101        ARICA       400      410     41001        6.5
# 1        ...       15101        ARICA       400      410     41001        6.5
# 2        ...       15101        ARICA       400      410     41001        5.8
# 3        ...       15101        ARICA       400      410     41001        0.0
# 4        ...        1101      IQUIQUE       400      410     41001        4.1
# ...      ...         ...          ...       ...      ...       ...        ...
# 3237038  ...        8110   TALCAHUANO         0        0         0        0.0
# 3237039  ...       13125    QUILICURA         0        0         0        6.5
# 3237040  ...        8306   NACIMIENTO         0        0         0        5.0
# 3237041  ...        8301  LOS ÁNGELES         0        0         0        6.6
# 3237042  ...        8313       YUMBEL         0        0         0        6.6
#
#          ASISTENCIA  SIT_FIN SIT_FIN_R  COD_MEN
# 0                98        P         P        0
# 1                98        P         P        0
# 2                90        P         P        0
# 3                 0        Y         Y        0
# 4                70        R         R        0
# ...             ...      ...       ...      ...
# 3237038           0        Y         Y        0
# 3237039         100        P         P        0
# 3237040         100        P         P        0
# 3237041         100        P         P        0
# 3237042         100        P         P        0
#
# [3237043 rows x 37 columns]

# %%
#Este codigo genera el dataframe filtrado del rendimiento
df_rendimiento = df_rendimiento[df_rendimiento['EDAD_ALU'] != ' ']
df_rendimiento_rm = df_rendimiento[df_rendimiento.COD_REG_RBD == 13]
df_rendimiento_rm = df_rendimiento_rm.loc[(df_rendimiento.EDAD_ALU == 18) | (df_rendimiento.EDAD_ALU == 17)]
df_rendimiento_rm_promedio = df_rendimiento_rm.groupby('NOM_COM_RBD').mean().reset_index()
df_rendimiento_rm_promedio = df_rendimiento_rm_promedio[['COD_COM_RBD','COD_DEPE2' ,'PROM_GRAL', 'ASISTENCIA']]

# %%
df_filtrado = pd.read_csv('Dataframes/rendimiento_filtrado_2021.csv')
comunas = df_rendimiento[['COD_COM_RBD', 'NOM_COM_RBD']]
df_final_filtrado = pd.merge(df_filtrado, comunas, on = 'COD_COM_RBD')
df_final_filtrado = df_final_filtrado.drop_duplicates().reset_index()
df_final_filtrado = df_final_filtrado[['COD_COM_RBD','COD_DEPE2','PROM_GRAL','ASISTENCIA','NOM_COM_RBD']]
df_final_filtrado
df_final_filtrado.to_csv('Dataframes/rendimiento_filtrado_2021.csv',index = False)

# %% [markdown]
# Finalmente queda generado un dataframe con los datos promedios por comuna.

# %% [markdown]
# **Analisis exploratorio de datos**

# %% [markdown]
# Se plantea separar a los colegios para evaluar los resultados separandolos por tramos de calificaciones:
# promedio menor a 5.0
# promedio entre 5.0 y 5.5
# promedio entre 5.5 y 5.9
# promedio mayor a 5.9

# %%
#df_distritos = pd.read_csv('Dataframes/comunas_por_distrito.csv')
datos_por_criterio = df_final_filtrado[df_final_filtrado.PROM_GRAL<5.0]
fig, ax1 = plt.subplots(figsize=(15, 15))
sns.barplot(x = 'NOM_COM_RBD', y = 'PROM_GRAL', data = datos_por_criterio, ax = ax1)
sns.despine(fig)

# %%
datos_por_criterio = df_final_filtrado.loc[(df_final_filtrado.PROM_GRAL >5.0) & (df_final_filtrado.PROM_GRAL <5.5)]
fig, ax1 = plt.subplots(figsize=(30, 15))
sns.barplot(x = 'NOM_COM_RBD', y = 'PROM_GRAL', data = datos_por_criterio, ax = ax1)
sns.despine(fig)

# %%
datos_por_criterio = df_final_filtrado.loc[(df_final_filtrado.PROM_GRAL >5.5) & (df_final_filtrado.PROM_GRAL <5.9)]
fig, ax1 = plt.subplots(figsize=(15, 15))
sns.barplot(x = 'NOM_COM_RBD', y = 'PROM_GRAL', data = datos_por_criterio, ax = ax1)
sns.despine(fig)

# %%
datos_por_criterio = df_final_filtrado[df_final_filtrado.PROM_GRAL >5.9]
fig, ax1 = plt.subplots(figsize=(15, 15))
sns.barplot(x = 'NOM_COM_RBD', y = 'PROM_GRAL', data = datos_por_criterio, ax = ax1)
sns.despine(fig)

# %% [markdown]
# Notamos que si bien las comunas con mas ingresos son aquellas que estan en el intervalo mas alto de calificaciones en promedio, no necesariamente eso significa que sea debido a la cantidad de ingresos ya que existen otras comunas de menores ingresos que tambien poseen resultados altos.
