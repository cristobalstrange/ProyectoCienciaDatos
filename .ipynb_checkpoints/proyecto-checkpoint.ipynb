# %%
#librerias
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn

# %%
df = pd.read_excel("Dataframes/basedefinitivaindices_2005-2022.xlsx")

# %%
df_rendimiento = pd.read_csv('Dataframes/20220302_Rendimiento_2021_20220131_WEB.csv', sep = ';')
df_rendimiento.head()
# Out:
# C:\Users\ibgar\AppData\Local\Temp\ipykernel_20348\1460839134.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_rendimiento = pd.read_csv('Dataframes/20220302_Rendimiento_2021_20220131_WEB.csv', sep = ';')
#    AGNO  RBD  DGV_RBD                  NOM_RBD  COD_REG_RBD NOM_REG_RBD_A  \
# 0  2021    1        9  LICEO POLITECNICO ARICA           15           AYP
# 1  2021    1        9  LICEO POLITECNICO ARICA           15           AYP
# 2  2021    1        9  LICEO POLITECNICO ARICA           15           AYP
# 3  2021    1        9  LICEO POLITECNICO ARICA           15           AYP
# 4  2021    1        9  LICEO POLITECNICO ARICA           15           AYP
#
#    COD_PRO_RBD  COD_COM_RBD NOM_COM_RBD  COD_DEPROV_RBD  ... COD_COM_ALU  \
# 0          151        15101       ARICA             151  ...       15101
# 1          151        15101       ARICA             151  ...       15101
# ...

# %%
df_rendimiento_rm = df_rendimiento[df_rendimiento.COD_REG_RBD == 13]
df_rendimiento_rm
# Out:
#          AGNO    RBD  DGV_RBD                                    NOM_RBD  \
# 1232579  2021   8485        9                   LICEO INSTITUTO NACIONAL
# 1232580  2021   8485        9                   LICEO INSTITUTO NACIONAL
# 1232581  2021   8485        9                   LICEO INSTITUTO NACIONAL
# 1232582  2021   8485        9                   LICEO INSTITUTO NACIONAL
# 1232583  2021   8485        9                   LICEO INSTITUTO NACIONAL
# ...       ...    ...      ...                                        ...
# 3236367  2021  41859        5  ESCUELA BASICA COLEGIO TRIGALES DEL MAIPO
# 3236368  2021  41859        5  ESCUELA BASICA COLEGIO TRIGALES DEL MAIPO
# 3236369  2021  41859        5  ESCUELA BASICA COLEGIO TRIGALES DEL MAIPO
# 3236370  2021  41859        5  ESCUELA BASICA COLEGIO TRIGALES DEL MAIPO
# 3236371  2021  41859        5  ESCUELA BASICA COLEGIO TRIGALES DEL MAIPO
#
#          COD_REG_RBD NOM_REG_RBD_A  COD_PRO_RBD  COD_COM_RBD  NOM_COM_RBD  \
# ...
